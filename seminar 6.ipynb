# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy import integrate

# %%
M1 = np.random.normal(40*1e4, 0.05*1e4, 1000)
M2 = np.random.normal(30*1e4, 0.1*1e4, 1000)
r = np.random.normal(3.2, 0.01, 1000)
G = 6.67384*1e-11

# %%
F = G*M1*M2/r**2

# %%
# Generate some data for this demonstration.
#data = norm.rvs(10.0, 2.5, size=500)

# Fit a normal distribution to the data:
mu, std = norm.fit(F)

# Plot the histogram.
plt.hist(F, bins=25, density=True, alpha=0.6, color='g')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()
print('mu =', mu, 'std =', std)
# Out:
# mu = 0.782265879469 std = 0.00553268158496

# %%
sigmaM1 = 0.05*1e4
sigmaM2 = 0.1*1e4
sigmar = 0.01
_1 = (G*M2/r**2)*sigmaM1
_2 = (G*M1/r**2)*sigmaM2
_3 = (-2*G*M1*M2/r**3)*sigmar
sigmaF = np.mean(np.sqrt(_1**2 + _2**2 + _3**2))
print('std =', sigmaF)
# Out:
# std = 0.00562685723166

# %% [markdown]
# Второй набор данных

# %%
_M1 = np.random.normal(40*1e4, 2*1e4, size=1000)
_M2 = np.random.normal(30*1e4, 10*1e4, size=1000)
_r = np.random.normal(3.2, 1, size=1000)

# %%
_F = G*_M1*_M2/_r**2
plt.plot(_r, _F, 'o')
plt.show()

# %%
# Generate some data for this demonstration.
#data = norm.rvs(10.0, 2.5, size=500)

# Fit a normal distribution to the data:
mu, std = norm.fit(_F[_F < 30])

# Plot the histogram.
plt.hist(_F[_F < 30], bins=25, density=True, alpha=0.6, color='g')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()
print('mu =', mu, 'std =', std)
# Out:
# mu = 1.14117524862 std = 1.44098183836

# %%
sigma_M1 = 0.05*1e4
sigma_M2 = 0.1*1e4
sigma_r = 0.01
_11 = (G*_M2/_r**2)*sigmaM1
_22 = (G*_M1/_r**2)*sigmaM2
_33 = (-2*G*_M1*_M2/_r**3)*sigmar
sigma_F = np.mean(np.sqrt(_11**2 + _22**2 + _33**2))
print('std =', sigma_F)
# Out:
# std = 0.0154481206133

# %% [markdown]
# ADD SEED!

# %%
def fourier(_x):
    for i in range (np.shape(x)):
        for k in range(len(np.size(_x))):
        s = _x*np.exp(i)
        x[i] = np.sum([])
